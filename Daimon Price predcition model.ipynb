# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
df = pd.read_csv("diamonds.csv")
df.sample(5)
df.shape

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
lr.fit(X_train, y_train)
print("Train score:", lr.score(X_train, y_train))
print("Test score:", lr.score(X_test, y_test))
y_pred = lr.predict(X_test)
df.plot.scatter(x = "carat", y = "price")
target = df["price"]
features = df[["carat","depth"]]
lr =LinearRegression()
lr.fit(features,target)
a=lr.score(features,target)
print('score:',a)
b=lr.predict([[0.3, 60]])
print("price:","Rs",b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12 df.sample(5)
#      13 df.shape
# ---> 15 X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
#      16 lr.fit(X_train, y_train)
#      17 print("Train score:", lr.score(X_train, y_train))
#
# NameError: name 'features' is not defined

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')


import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


df = pd.read_csv("diamonds.csv")


print("Sample rows from the dataset:")
print(df.sample(5))
print("\nShape of dataset:", df.shape)

features = df[["carat", "depth"]]
target = df["price"]


df.plot.scatter(x="carat", y="price", alpha=0.5)
plt.title("Carat vs Price")
plt.grid(True)
plt.show()


X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)


lr = LinearRegression()
lr.fit(X_train, y_train)


train_score = lr.score(X_train, y_train)
test_score = lr.score(X_test, y_test)
full_score = lr.score(features, target)

print(" Train Score:", round(train_score, 4))
print(" Test Score:", round(test_score, 4))
print(" Full Dataset Score:", round(full_score, 4))

# 🔮 Prediction example: carat=0.3, depth=60
predicted_price = lr.predict([[0.3, 60]])[0]
print("Predicted Price for 0.3 carat & 60 depth: Rs", round(predicted_price, 2))
# Out:
# Sample rows from the dataset:
#            s  carat      cut color clarity  depth  table  price     x     y  \
# 26266  26267   2.24    Ideal     I     SI2   62.1   53.6  15730  8.38  8.41
# 43377  43378   0.50  Premium     F     SI1   62.5   59.0   1409  5.03  4.99
# 16613  16614   1.20    Ideal     I     VS1   62.5   55.0   6639  6.76  6.81
# 47772  47773   0.51     Good     G    VVS2   63.7   54.0   1895  5.10  5.08
# 30215  30216   0.33  Premium     E     VS2   60.7   58.0    723  4.47  4.49
#
#           z
# 26266  5.21
# 43377  3.13
# 16613  4.24
# 47772  3.24
# 30215  2.72
#
# Shape of dataset: (53940, 11)
#  Train Score: 0.8507
#  Test Score: 0.8506
#  Full Dataset Score: 0.8507
# Predicted Price for 0.3 carat & 60 depth: Rs 237.78
