# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("mpg.csv")
# show 5 random rows from the dataset
df.sample(5)

df.plot.scatter(x = "Horsepower", y = "MPG")
target = df["MPG"]
features = df[["Horsepower","Weight"]]
lr = LinearRegression()
lr.fit(features,target)
#Higher the score, better the model.
lr.score(features,target)
lr.predict([[47,3000]])
# 29.3216098 miles per gallon is the mileage of a car with HorsePower = 100 and Weight = 2000
# 1 gallon= 3.785
#why linear regression
#Fast training time 
#Easily interpretable results you can clearly see how much each feature affects MPG)
#Good performance when the data does not require complex modeling
#Technical Benefits:
#Low variance and low computational cost
#Works well when multicollinearity is minimal
#Coefficients help understand how much MPG changes with a 1-unit change in horsepower or weight
# Out:
# array([26.03450418])

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')


import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt


df = pd.read_csv("mpg.csv")

# Horsepower vs MPG
df.plot.scatter(x="Horsepower", y="MPG")
plt.title("Horsepower vs MPG")
plt.show()

# features and target
features = df[["Horsepower", "Weight"]]
target = df["MPG"]


X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

Train the model
lr = LinearRegression()
lr.fit(X_train, y_train)


train_score = lr.score(X_train, y_train)
test_score = lr.score(X_test, y_test)

print("✅ Train Score:", round(train_score, 4))
print("✅ Test Score:", round(test_score, 4))


prediction = lr.predict([[47, 3000]])[0]
print(f"Predicted MPG for Horsepower=47, Weight=3000: {prediction:.2f}")

prediction_2 = lr.predict([[100, 2000]])[0]
print(f"Predicted MPG for Horsepower=100, Weight=2000: {prediction_2:.2f} miles/gallon")
print(f"In liters: {prediction_2 * 3.785:.2f} km/l")
# Out:
# ✅ Train Score: 0.6875
# ✅ Test Score: 0.7759
# Predicted MPG for Horsepower=47, Weight=3000: 26.38
# Predicted MPG for Horsepower=100, Weight=2000: 29.41 miles/gallon
# In liters: 111.31 km/l
